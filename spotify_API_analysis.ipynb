# %%
import requests
import requests
import base64
import json
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
#https://stmorse.github.io/journal/spotify-api.html

# %%
CLIENT_ID ='9997f3bfb55e4892b1955c31b543402e'
CLIENT_SECRET ='29799e7c440b43cfbb80b6e19746e63f'

# %%
AUTH_URL= 'https://accounts.spotify.com/api/token'

# %%
#post

auth_response= requests.post(AUTH_URL, {
     "grant_type": "client_credentials", 
    "client_id" : CLIENT_ID,
    "client_secret" : CLIENT_SECRET,
})

# %%
#convert the response to JSON

auth_response_data = auth_response.json()

# save the access token

access_token= auth_response_data['access_token']
access_token
# Out:
# 'BQAYSrlh0bgW3MDfNg0rZOs3tXQQYOGACEg2xSK9T0m7Prr0AQIdyxSA3sq7vqSyXU_C7UBcYlxJXAfzXeA'

# %%
headers= {
    'Authorization': 'Bearer BQAYSrlh0bgW3MDfNg0rZOs3tXQQYOGACEg2xSK9T0m7Prr0AQIdyxSA3sq7vqSyXU_C7UBcYlxJXAfzXeA','User-Agent': 'LAMA'
}

# %%
# base URL of all Spotify API endpoints

BASE_URL= 'https://api.spotify.com/v1/'

# track ID from the URI

track_id = '0fIffclhgJC5h8AdMMVvkp' # welcome to the party

# %%
#https://open.spotify.com/album/7ycBtnsMtyVbbwTfJwRjSP?si=TKQju6xAQFipycH-IDtDgA

# %%
# # actual GET request with proper header

r= requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)
r= r.json()
r
# Out:
# {'danceability': 0.637,
#  'energy': 0.723,
#  'key': 2,
#  'loudness': -5.547,
#  'mode': 1,
#  'speechiness': 0.091,
#  'acousticness': 0.0134,
#  'instrumentalness': 7.87e-05,
#  'liveness': 0.196,
#  'valence': 0.228,
#  'tempo': 143.013,
#  'type': 'audio_features',
#  'id': '0fIffclhgJC5h8AdMMVvkp',
#  'uri': 'spotify:track:0fIffclhgJC5h8AdMMVvkp',
#  'track_href': 'https://api.spotify.com/v1/tracks/0fIffclhgJC5h8AdMMVvkp',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fIffclhgJC5h8AdMMVvkp',
#  'duration_ms': 214960,
#  'time_signature': 4}

# %%
#i= pd.json_normalize(r, record_path= 'audio-features' )
#i= i.json()
#i

# %%
#r= requests.get(' https://api.spotify.com/v1/albums/TKQju6xAQFipycH-IDtDgA', headers=headers)

# %% [markdown]
# ### getting albums

# %%
artist_id = '2YZyLoL8N0Wb9xBt1NhZWg' # kendrik lamar

# pull all artists albums
r = requests.get(BASE_URL + 'artists/' + artist_id + '/albums', 
                 headers=headers, 
                params={'include_groups': 'album', 'limit': 20})
d = r.json()

# %%
d
# Out:
# {'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg/albums?offset=0&limit=20&include_groups=album',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#      'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#      'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#      'name': 'Kendrick Lamar',
#      'type': 'artist',
#      'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#      'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#      'id': '7tYKF4w9nC0nq9CsPZTHyP',
#      'name': 'SZA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
# ...

# %%
c= pd.json_normalize(d, record_path='items' )
c.head()
# Out:
#   album_group album_type                                            artists  \
# 0       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 1       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 2       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 3       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 4       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 1                                               [MX]
# 2  [AE, AU, BH, BY, CA, DZ, EG, ID, IN, JO, KW, K...
# 3  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 4                                               [MX]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/3pLdWdkj83EY...  3pLdWdkj83EYfDN6H2N8MR
# ...

# %% [markdown]
# ### cleaning

# %%
c.shape
# Out:
# (20, 14)

# %%
new_col= c[[ 'name','artists',   'id', 'release_date', 'total_tracks','type','available_markets']]

# %%
new_col.head()
# Out:
#                                                 name  \
# 0  Black Panther The Album Music From And Inspire...
# 1  Black Panther The Album Music From And Inspire...
# 2  Black Panther The Album Music From And Inspire...
# 3                          DAMN. COLLECTORS EDITION.
# 4                          DAMN. COLLECTORS EDITION.
#
#                                              artists                      id  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  3pLdWdkj83EYfDN6H2N8MR
# 1  [{'external_urls': {'spotify': 'https://open.s...  4Kp52vGJe5oVi0EXNhSDKy
# 2  [{'external_urls': {'spotify': 'https://open.s...  5sOSzueqgCiVpXNcpd6QpL
# 3  [{'external_urls': {'spotify': 'https://open.s...  4alcGHjstaALJHHiljfy3H
# 4  [{'external_urls': {'spotify': 'https://open.s...  1LLOGSa5ehwSWrPg1Qc3Vg
#
#   release_date  total_tracks   type  \
# 0   2018-02-09            14  album
# 1   2018-02-09            14  album
# 2   2018-02-08            14  album
# ...

# %%
gd= new_col.drop_duplicates(subset=['name'])
gd
# Out:
#                                                  name  \
# 0   Black Panther The Album Music From And Inspire...
# 3                           DAMN. COLLECTORS EDITION.
# 6                                               DAMN.
# 9                                untitled unmastered.
# 10                                To Pimp A Butterfly
# 14                    good kid, m.A.A.d city (Deluxe)
# 15                             good kid, m.A.A.d city
#
#                                               artists                      id  \
# 0   [{'external_urls': {'spotify': 'https://open.s...  3pLdWdkj83EYfDN6H2N8MR
# 3   [{'external_urls': {'spotify': 'https://open.s...  4alcGHjstaALJHHiljfy3H
# 6   [{'external_urls': {'spotify': 'https://open.s...  4eLPsYPBmXABThSJ821sqY
# 9   [{'external_urls': {'spotify': 'https://open.s...  0kL3TYRsSXnu0iJvFO3rud
# 10  [{'external_urls': {'spotify': 'https://open.s...  76cek8jEdNsxH60aUu8Qtj
# ...

# %% [markdown]
# ### analysis

# %%
# Groupby releasee data and available market

# %%
#gd.groupby('available_markets')['total_tracks'].mean()

# %%
# Pull all tracks from this albumns

# %%
p = requests.get(BASE_URL + 'albums/'+ '2ioBMJIiOANfeCaXP9a7Zn' + '/tracks', 
                headers= headers)
tracks= p.json()['items']
tracks
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#     'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#     'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#     'name': 'Kendrick Lamar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#   'available_markets': ['CA'],
#   'disc_number': 1,
#   'duration_ms': 273640,
#   'explicit': True,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/41yVyNb4HAPvbnFUn4qR12'},
#   'href': 'https://api.spotify.com/v1/tracks/41yVyNb4HAPvbnFUn4qR12',
#   'id': '41yVyNb4HAPvbnFUn4qR12',
#   'is_local': False,
#   'name': 'Sherane a.k.a Master Splinter’s Daughter',
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:41yVyNb4HAPvbnFUn4qR12'},
#  {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
# ...

# %%
data= []
albums= []

for track in tracks:
    f = requests.get(BASE_URL + 'audio-features/' + '2ioBMJIiOANfeCaXP9a7Zn' , 
            headers=headers)
    f = f.json()

    f.update({
        'track_name': track['name'],
        'album_name': album_name,
        'short_album_name': trim_name,
        'release_date': album['release_date'],
        'album_id': album['id']
        
    })
    
    data.append(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-3065e2660b65> in <module>
#       9     f.update({
#      10         'track_name': track['name'],
# ---> 11         'album_name': album_name,
#      12         'short_album_name': trim_name,
#      13         'release_date': album['release_date'],
#
# NameError: name 'album_name' is not defined

# %%
audio_album
# Out:
# {'error': {'status': 404, 'message': 'Service not found'}}

# %%
a
# Out:
# name
# Black Panther The Album Music From And Inspired By    3
# DAMN.                                                 3
# DAMN. COLLECTORS EDITION.                             3
# To Pimp A Butterfly                                   4
# good kid, m.A.A.d city                                2
# good kid, m.A.A.d city (Deluxe)                       4
# untitled unmastered.                                  1
# Name: total_tracks, dtype: int64

# %% [markdown]
# #### available markets

# %%
new_col['available_markets'].count()
# Out:
# 7

# %%
gd
# Out:
#                                                  name  \
# 0   Black Panther The Album Music From And Inspire...
# 3                           DAMN. COLLECTORS EDITION.
# 6                                               DAMN.
# 9                                untitled unmastered.
# 10                                To Pimp A Butterfly
# 14                    good kid, m.A.A.d city (Deluxe)
# 15                             good kid, m.A.A.d city
#
#                                               artists                      id  \
# 0   [{'external_urls': {'spotify': 'https://open.s...  3pLdWdkj83EYfDN6H2N8MR
# 3   [{'external_urls': {'spotify': 'https://open.s...  4alcGHjstaALJHHiljfy3H
# 6   [{'external_urls': {'spotify': 'https://open.s...  4eLPsYPBmXABThSJ821sqY
# 9   [{'external_urls': {'spotify': 'https://open.s...  0kL3TYRsSXnu0iJvFO3rud
# 10  [{'external_urls': {'spotify': 'https://open.s...  7ycBtnsMtyVbbwTfJwRjSP
# ...

# %%
# little bar charts and pie charts
